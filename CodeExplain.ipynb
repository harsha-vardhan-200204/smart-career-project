# %% [markdown]
# ## App.py

# %% [markdown]
#  #### This code creates a web app using Flask that predicts a career based on user details.

# %% [markdown]
# ### 1.Import libraries

# %%
from flask import Flask, render_template, request
import pandas as pd
import joblib

# %%
Flask → Creates the website/web app. OR Website builder
Pandas → Handles data in table format. OR Data organizer
Joblib → Loads saved AI/ML models. OR Model loader

# %% [markdown]
# #### 2. Create Flask app

# %%
app = Flask(__name__)

# %%
This creates your web application.
Like saying:
“Start my website.

# %% [markdown]
# ### 3. Load trained model

# %%
model = joblib.load("career_guidance_model.pkl")

# %%
This loads trained machine learning model.

This model already learned from old data and now can predict careers.

Example:

If input is:

Age = 22
Education = MCA
Skills = Python
Interest = AI
Score = 85

Model may predict:

Data Scientist

# %% [markdown]
# ### 4. Load encoders

# %%
education_encoder = joblib.load("education_encoder.pkl")
skills_encoder = joblib.load("skills_encoder.pkl")
interests_encoder = joblib.load("interests_encoder.pkl")
career_encoder = joblib.load("career_encoder.pkl")

# %%
Computers cannot directly understand text like:

"MCA"
"Python"
"AI"

So encoders convert words into numbers.

Example:

Text	  Number
MCA     	2
BCA	        1
Python	    5

Machine learning models work with numbers, not text.

# %% [markdown]
# ### 5. Home page route

# %%
@app.route("/")
def home():
    return render_template("index.html")

# %%
This loads your homepage.
When user opens:

http://127.0.0.1:5000
Flask shows:

index.html

That is your input form page.

# %% [markdown]
# ### 6. Prediction route

# %%
@app.route("/predict", methods=["POST"])
def predict():

# %%
When user fills the form and clicks submit, this function runs.

# %% [markdown]
# ### 7. Get user input

# %%
age = float(request.form["age"])

# %%
Gets age from form.
Example:
User enters: 22
Then: age = 22.0
Same for other inputs:
->education_input
->skills_input
->interests_input
->score
Example:
->Age = 22
->Education = MCA
->Skills = Python
->Interests = AI
->Score = 85

# %% [markdown]
# ### 8. Clean input

# %%
.strip()

# %%
Removes extra spaces.
Example: " MCA "
becomes: "MCA"
This avoids errors.

# %% [markdown]
# ### 9. Encode text to numbers

# %%
education = education_encoder.transform([education_input])[0]

# %%
Converts text into number.
Example:
"MCA" → 2
"Python" → 5
"AI" → 3
Now computer can understand it.

# %% [markdown]
# ### 10. Create input data

# %%
input_data = pd.DataFrame([[
    age,
    education,
    skills,
    interests,
    score
]])

# %%
Creates data in table form.
Example:

Age	Education	Skills	Interests	Score
22  	2	      5	       3	     85

This is what model needs.

# %% [markdown]
# ### 11. Predict career

# %%
prediction = model.predict(input_data)

# %%
Model checks the input and predicts career.
Example output:
[4]

# %% [markdown]
# ### 12. Convert number back to career name

# %%
career_name = career_encoder.inverse_transform(prediction)[0]

# %%
Converts number to actual career name.
Example: 4 → Software Engineer
So user sees:
Predicted Career: Software Engineer

# %% [markdown]
# ### 13. Show result on webpage

# %%
return render_template(
    "index.html",
    prediction_text=f"Predicted Career: {career_name}"
)

# %%
This sends result back to webpage.
Example on screen:
Predicted Career: Data Scientist

# %% [markdown]
# ### 14. Error handling

# %%
except Exception as e:

# %%
If something goes wrong, program doesn't crash.
Example:
If user enters wrong value:
abc instead of age

It shows:
Input Error
instead of stopping the app.

# %% [markdown]
# ### 15. Run the app

# %%
if __name__ == "__main__":

# %%
app.run(
    host="127.0.0.1",
    port=5000,
    debug=False
)

# %%
Your app runs at:

http://127.0.0.1:5000

Open it in browser.

# %%
Overall flow

User enters details → Text converts to numbers → Model predicts → Number converts to career name → Result shown on webpage.

Like this:

User Input
   ↓
Encoder
   ↓
ML Model
   ↓
Career Prediction
   ↓
Show on Website

# %% [markdown]
# ## Index.html

# %% [markdown]
# ### 1. HTML document start

# %%
<!DOCTYPE html>
<html lang="en">

# %%
This tells browser:

“This is an HTML5 webpage.”

lang="en" means English language.

# %% [markdown]
# ### 2. Head section

# %%
<head>

# %% [markdown]
# ### Character settings

# %%
<meta charset="UTF-8">

# %%
Allows special characters and symbols.
Example:

₹ © ✓ etc.

# %% [markdown]
# ### Mobile responsive design

# %%
<meta name="viewport" content="width=device-width, initial-scale=1.0">

# %%
Makes your website fit mobile screens properly.
Without this, mobile UI may look broken.

# %% [markdown]
# #### Website title

# %%
<title>Smart Career Guidance AI</title>

# %% [markdown]
# ### 3. Connect CSS

# %%
<link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">

# %%
This loads your CSS file.

In Flask:

{{ url_for(...) }} finds the CSS file automatically.

So Flask loads:

static/style.css

This gives colors, animations, spacing, buttons, etc.

# %% [markdown]
# ### 4. Font Awesome icons

# %%
<link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0/css/all.min.css" rel="stylesheet">

# %%
This loads icons from Font Awesome.
Examples:
🎓 graduation icon
🚀 rocket icon
❤️ heart icon
That makes UI look modern.

# %% [markdown]
# ### 5. Body section

# %%
<body>
Everything visible to users is inside body.

# %% [markdown]
# ### 6. Main container

# %%
<div class="container">
This creates the main box.
Think of it like:
A card that contains your full app.

# %% [markdown]
# ### 7. Header section

# %%
<div class="header">
This top section shows app branding.

# %% [markdown]
# #### Rocket icon

# %%
<i class="fas fa-rocket icon"></i>
Shows 🚀 icon.
Meaning:
Fast AI system

# %% [markdown]
# #### Title

# %%
<h1 class="title">
Smart Career Guidance For Women
</h1>
    Main heading of your project.

# %% [markdown]
# #### Subtitle

# %%
<p class="subtitle">
AI Powered Career Recommendation System
</p>
    Short description.

# %% [markdown]
# ### 8. Form

# %%
<form action="/predict" method="POST" onsubmit="showLoader()">

# %%
This creates input form.
When user clicks submit:
Data goes to Flask route:
/predict
Using POST method.
Also calls JavaScript function:
showLoader()

# %% [markdown]
# ### 9. Age input

# %%
<input type="number" name="age">

# %%
User enters age.
Restrictions:
min="18" max="65"
Only age between 18–65 allowed.
Good validation.

# %% [markdown]
# ### 10. Education input

# %%
<input type="text" name="education">
User enters education.
Example:
BCA
MCA
BE
BTech

# %% [markdown]
# ### 11. Skills input

# %%
<input type="text" name="skills">
User enters skills.
Example:
Python
Java
AI
Communication

# %% [markdown]
# ### 12. Interests input

# %%
<input type="text" name="interests">
Example:
Coding
Design
Research

# %% [markdown]
# ### 13. Score input

# %%
<input type="number" name="score">

# %%
Example: 85.5
Restrictions:
min="0" max="100"
Only valid score allowed.

# %% [markdown]
# ### 14. Submit button

# %%
<button type="submit" id="predictBtn">

# %%
This creates the prediction button.
Shows icon + text:
✨ Predict My Career
When clicked, sends data to Flask backend.

# %% [markdown]
# ### 15. Loader animation

# %%
<div id="loader" class="loader"></div>

# %%
This is loading animation.
When prediction is happening, spinner shows.
Example:
⏳ Loading...
This improves user experience.

# %% [markdown]
# ### 16. Result section

# %%
{% if prediction_text %}
This is Flask/Jinja template syntax.
If backend sends prediction:

# %%
Example:
prediction_text = "Predicted Career: Data Scientist"

Then this displays it.
Example on webpage:
Predicted Career: Data Scientist

# %% [markdown]
# ### 17. JavaScript

# %%
<script>

# %%
Function
function showLoader()
Runs when user clicks button.

# %%
Show loader
document.getElementById("loader").style.display = "block";
Shows loading spinner.

# %%
Change button text
document.getElementById("predictBtn").innerHTML =
'<i class="fas fa-spinner fa-spin"></i> Analyzing...';
Button changes from:
Predict My Career
to
⏳ Analyzing...
Disable button
document.getElementById("predictBtn").disabled = true;
Prevents user clicking multiple times.
Very useful.

# %%
Full flow

User opens webpage
↓
Enters details
↓
Clicks Predict
↓
Loader appears
↓
Data goes to Flask backend
↓
ML model predicts career
↓
Result shown on screen
